# %%
# %run Assignment4.py
# Out:
# Optimal Value: 2
# Optimal Value: 5
# Optimal Value: 1
# Optimal Value: 1
# Confusion Matrixes:
# Classifier           TP         FN         FP         TN
# Logistic Regression  82         2          3          31
# kNN                  79         5          1          33
# Dummy                84         0          34         0
#
# Metrics:
# Classifier           Accuracy(%)  Precision(%) TPR(%)  FPR(%)  F1 Score(%)
# Logistic Regression  0.96         0.96         0.98    0.09    0.97
# kNN                  0.95         0.99         0.94    0.03    0.96
# Dummy                0.71         0.71         1.00    1.00    0.83
